# %% [markdown]
# # Copula Example
#
# This compact notebook demonstrates dependencies between underwriting-risk components using PAL's public API. Stored execution output is intentionally omitted so the notebook stays lightweight and reproducible.

# %%
from pal import config
from pal.copulas import GumbelCopula, StudentsTCopula
from pal.distributions import GPD, Gamma, Normal, Poisson
from pal.frequency_severity import FrequencySeverityModel
from pal.variables import ProteusVariable

config.n_sims = 100_000
lobs = ["Motor", "Property", "Liability", "Marine", "Aviation"]

large_losses = ProteusVariable(
    "class",
    {
        lob: FrequencySeverityModel(
            Poisson(mean=5),
            GPD(shape=0.33, scale=100_000, loc=1_000_000),
        ).generate()
        for lob in lobs
    },
)

attritional_losses = ProteusVariable(
    "class",
    {lob: Gamma(alpha=i + 1, theta=1_000_000).generate() for i, lob in enumerate(lobs)},
)

# %%
aggregate_large_losses = ProteusVariable("class", {lob: (large_losses[lob] * 1.05).aggregate() for lob in lobs})

for lob in lobs:
    GumbelCopula(theta=1.2).apply([aggregate_large_losses[lob], attritional_losses[lob]])

total_losses = aggregate_large_losses + attritional_losses
correlation_matrix = [
    [1.0, 0.5, 0.3, 0.2, 0.1],
    [0.5, 1.0, 0.4, 0.3, 0.2],
    [0.3, 0.4, 1.0, 0.5, 0.4],
    [0.2, 0.3, 0.5, 1.0, 0.6],
    [0.1, 0.2, 0.4, 0.6, 1.0],
]
StudentsTCopula(correlation_matrix, 5, "linear").apply(total_losses)

inflation = Normal(0.05, 0.02).generate()
inflated_losses = total_losses * (1 + inflation)
total = inflated_losses.sum()
print("TVaR 99%:", total.tvar(99))
inflated_losses.rank_scatter_plot(title="Rank scatter plots by line of business")
